# %%
import uproot
import numpy as np
import awkward as ak

from coffea.nanoevents import NanoEventsFactory, BaseSchema
from agc_schema import AGCSchema

# %%
import json
with open('ntuples_with_tprime.json', 'r') as f:
    metadata = json.load(f)

# Function to calculate the integrated luminosity in case we couldn't access all of the files
def getLumi(nevts):
    lumi_nom = 2256.38 # total possible luminosity in /pb
    sf = float(nevts)/36619019
    return lumi_nom*sf 

# Useful function to calculate weight, pass the sample name, 
# total_events summed over files accessed and lumi calculated from function above
def getEventWeight(sample,n_total_events,lumi):
    if sample != "data": # we don't weight the real data
        xsec_weight = metadata[sample]['filter_eff']*metadata[sample]['xsec'] * lumi / (n_total_events)
    else:
        xsec_weight = 1
    return xsec_weight

# %%
# define the binning for my observable (m_bjj)
obsbins=np.arange(500,2080,80)

# %%
# define a function that will run over the analysis for any input file 

import time
import matplotlib.pyplot as plt

def runAnalysis(input_file,isMC=True):
    try: 
        events = NanoEventsFactory.from_root(input_file, schemaclass=AGCSchema, treepath='events').events()
    except OSError:
        time.sleep(2) # sleep for 2 seconds and try one more time
        try: 
            events = NanoEventsFactory.from_root(input_file, schemaclass=AGCSchema, treepath='events').events()
        except OSError:
            time.sleep(2) # sleep for 2 seconds just to not try EOS again but give up on this file now
            return [],[]
    
    # Object selection
    selected_electrons = events.electron[(events.electron.pt > 30) & (abs(events.electron.eta)<2.1) & (events.electron.isTight == True) & (events.electron.sip3d < 4 )]
    selected_muons = events.muon[(events.muon.pt > 30) & (abs(events.muon.eta)<2.1) & (events.muon.isTight == True) & (events.muon.sip3d < 4) & (events.muon.pfreliso04DBCorr < 0.15)]
    selected_jets = events.jet[(events.jet.corrpt > 30) & (abs(events.jet.eta)<2.4) ]
    
    # Event selection
    event_filters = ((ak.count(selected_electrons.pt, axis=1) + ak.count(selected_muons.pt, axis=1)) == 1)
    
    # Separate event selection into signal region and control region 
    event_filters_CR = event_filters &  (ak.count(selected_jets.corrpt, axis=1) >= 4) & (ak.sum(selected_jets.btag >= 0.8, axis=1) < 1)
    event_filters_SR = event_filters &  (ak.count(selected_jets.corrpt, axis=1) >= 4) & (ak.sum(selected_jets.btag >= 0.8, axis=1) >= 2)
    
    selected_events_SR = selected_jets[event_filters_SR]
    selected_events_CR = selected_jets[event_filters_CR]
    
    # calculate scale up/down 
    if isMC:
        selected_events_SR['scaleUp']   = selected_events_SR.corrptUp/selected_events_SR.corrpt
        selected_events_SR['scaleDown'] = selected_events_SR.corrptDown/selected_events_SR.corrpt
        
        selected_events_CR['scaleUp']   = selected_events_CR.corrptUp/selected_events_CR.corrpt
        selected_events_CR['scaleDown'] = selected_events_CR.corrptDown/selected_events_CR.corrpt
    
    # Calculate observable for SR (mbjj)
    trijet = ak.combinations(selected_events_SR, 3, fields=["j1", "j2", "j3"])
    j1,j2,j3 = ak.unzip(trijet)
    has_bjet = (ak.sum(j1.btag>=0.8,axis=1)+ak.sum(j2.btag>=0.8,axis=1)+ak.sum(j3.btag>=0.8,axis=1)>0)
    trijet = trijet[has_bjet]
    trijet["p4"] = trijet.j1 + trijet.j2 + trijet.j3
    trijet_mass = trijet["p4"][ak.argmax(trijet.p4.pt, axis=1, keepdims=True)].mass
    observableSR = ak.flatten(trijet_mass).to_numpy()
     
    if isMC:
        trijet["p4Up"]   = trijet.j1.multiply(trijet.j1.scaleUp) +trijet.j2.multiply(trijet.j2.scaleUp)+trijet.j3.multiply(trijet.j3.scaleUp) 
        trijet["p4Down"] = trijet.j1.multiply(trijet.j1.scaleDown) +trijet.j2.multiply(trijet.j2.scaleDown)+trijet.j3.multiply(trijet.j3.scaleDown) 
        
        trijet_massU = trijet["p4Up"][ak.argmax(trijet.p4Up.pt, axis=1, keepdims=True)].mass
        trijet_massD = trijet["p4Down"][ak.argmax(trijet.p4Down.pt, axis=1, keepdims=True)].mass
    
        observableSRU = ak.flatten(trijet_massU).to_numpy()
        observableSRD = ak.flatten(trijet_massD).to_numpy()
    
    
    # Calculate observable for CR (mjjj)
    trijet = ak.combinations(selected_events_CR, 3, fields=["j1", "j2", "j3"])
    j1,j2,j3 = ak.unzip(trijet)
    trijet["p4"] = trijet.j1 + trijet.j2 + trijet.j3
    trijet_mass = trijet["p4"][ak.argmax(trijet.p4.pt, axis=1, keepdims=True)].mass
    observableCR = ak.flatten(trijet_mass).to_numpy()
    
    if isMC:
        trijet["p4Up"]   = trijet.j1.multiply(trijet.j1.scaleUp) +trijet.j2.multiply(trijet.j2.scaleUp)+trijet.j3.multiply(trijet.j3.scaleUp) 
        trijet["p4Down"] = trijet.j1.multiply(trijet.j1.scaleDown) +trijet.j2.multiply(trijet.j2.scaleDown)+trijet.j3.multiply(trijet.j3.scaleDown) 
        
        trijet_massU = trijet["p4Up"][ak.argmax(trijet.p4Up.pt, axis=1, keepdims=True)].mass
        trijet_massD = trijet["p4Down"][ak.argmax(trijet.p4Down.pt, axis=1, keepdims=True)].mass
    
        observableCRU = ak.flatten(trijet_massU).to_numpy()
        observableCRD = ak.flatten(trijet_massD).to_numpy()
    
    # create counts in bins 
    counts_bin_edgesSR  = plt.hist(observableSR,bins=obsbins)
    countsSR, bin_edgesSR = counts_bin_edgesSR[0],counts_bin_edgesSR[1]
    
    if isMC : 
        countsSRU_bin_edgesSR  = plt.hist(observableSRU,bins=obsbins)
        countsSRU, bin_edgesSR = countsSRU_bin_edgesSR[0],countsSRU_bin_edgesSR[1]
    
        countsSRD_bin_edgesSR  = plt.hist(observableSRD,bins=obsbins)
        countsSRD, bin_edgesSR = countsSRD_bin_edgesSR[0],countsSRD_bin_edgesSR[1]
    
    plt.clf()
    
    
    counts_bin_edgesCR  = plt.hist(observableCR,bins=obsbins)
    countsCR, bin_edgesCR = counts_bin_edgesCR[0],counts_bin_edgesCR[1]

   
    if isMC: 
        countsCRU_bin_edgesCR  = plt.hist(observableCRU,bins=obsbins)
        countsCRU, bin_edgesCR = countsCRU_bin_edgesCR[0],countsCRU_bin_edgesCR[1]
    
        countsCRD_bin_edgesCR  = plt.hist(observableCRD,bins=obsbins)
        countsCRD, bin_edgesCR = countsCRD_bin_edgesCR[0],countsCRD_bin_edgesCR[1]
    
    plt.clf()
    
    # return the counts 
    # return the counts 
    if isMC: 
        return {'nominal':np.array(countsSR),'jesUp':np.array(countsSRU),'jesDown':np.array(countsSRD)},{'nominal':np.array(countsCR),'jesUp':np.array(countsCRU),'jesDown':np.array(countsCRD)}
    else : return {'nominal':np.array(countsSR)},{'nominal':np.array(countsCR)}

# %%
from hist2df import * 

samples=[
    'data'
    ,'ttbar'
    ,'single_atop_t_chan'
    ,'single_top_t_chan'
    ,'single_top_tW'
    ,'wjets'
    ,'tprime'
]


n_sim_samples = len(samples)-1

# first run over the data. We want to keep track of the total number of events 
# that get accessed so that we can modify the integrated luminosity if necessary 

print('data')
countsSR = {'nominal':np.array([0. for i in range(len(obsbins)-1)])}
countsCR = {'nominal':np.array([0. for i in range(len(obsbins)-1)])}
total_events = 0

MAX_FILES = -1 # if a negative number, then we don't set a maximum on the number of files. 

for j,p in enumerate(metadata['data']['nominal']['files']): 
    
    # for each file, we add the counts from these events
    if (MAX_FILES > 0 and j > MAX_FILES): continue
    print(j,p['path'])

    event_countsSR,event_countsCR = runAnalysis(p['path'],isMC=False)
    if len(event_countsSR):
        countsSR['nominal'] += event_countsSR['nominal']
        countsCR['nominal'] += event_countsCR['nominal']
        total_events+=p['nevts'] 
 
    else : print("skipped file (XRootD error)")
    

intlumi = getLumi(total_events)
print("Data total events accessed", total_events, " -> %g /pb"%intlumi )
                 
# convert to dataframe 
dfs   = histogramToDataframe(countsSR['nominal'],"signalregion",'data')
dfsCR = histogramToDataframe(countsCR['nominal'],"controlregion",'data')
dfs = pd.concat([dfs,dfsCR],ignore_index=True)
                
# Now we run over the simulated samples. Again, we should keep track of the number of events  
# that get accessed so that we can calculate the right event_weight

for i,sample in enumerate(samples[1:]): 
    if sample=='data': continue # shouldn't need this 
    print(sample)
    
     # make sure to zero out the counts for each sample 
    countsSR = {
         'nominal':np.array([0. for i in range(len(obsbins)-1)])
        ,'jesUp':np.array([0. for i in range(len(obsbins)-1)])
        ,'jesDown':np.array([0. for i in range(len(obsbins)-1)])
    }
    countsCR = {
         'nominal':np.array([0. for i in range(len(obsbins)-1)])
        ,'jesUp':np.array([0. for i in range(len(obsbins)-1)])
        ,'jesDown':np.array([0. for i in range(len(obsbins)-1)])
    }
    total_sim_events = 0
    
    for j,p in enumerate(metadata[sample]['nominal']['files']): 
        
        if (MAX_FILES > 0 and j > MAX_FILES): continue
        print(j,p['path'])
        # for each file, we add the counts from these events
        event_countsSR,event_countsCR = runAnalysis(p['path'],isMC=True)
        if len(event_countsSR):
            countsSR['nominal'] += event_countsSR['nominal']
            countsCR['nominal'] += event_countsCR['nominal']
            
            countsSR['jesUp'] += event_countsSR['jesUp']
            countsCR['jesUp'] += event_countsCR['jesUp']
            
            countsSR['jesDown'] += event_countsSR['jesDown']
            countsCR['jesDown'] += event_countsCR['jesDown']
            total_sim_events+=p['nevts'] 
           
        else : print("skipped file (XRootD error)")
        
            
    event_weight = getEventWeight(sample,total_sim_events,intlumi)
    print("Total events processed (%s):"%(sample), total_sim_events, 
          "XSec = ",metadata[sample]['xsec'], 
          "Filter efficiency = ", metadata[sample]['filter_eff'], 
          "Event weight = ", event_weight)
        
    # now that we have the counts, we convert to a dataframe 
    dfs_sampleSRN = histogramToDataframe(countsSR['nominal'],"signalregion",sample)
    dfs_sampleCRN = histogramToDataframe(countsCR['nominal'],"controlregion",sample)
    
    dfs_sampleSRU = histogramToDataframe(countsSR['jesUp'],"signalregion",sample,sys='jesUp')
    dfs_sampleCRU = histogramToDataframe(countsCR['jesUp'],"controlregion",sample,sys='jesUp')
    
    dfs_sampleSRD = histogramToDataframe(countsSR['jesDown'],"signalregion",sample,sys='jesDown')
    dfs_sampleCRD = histogramToDataframe(countsCR['jesDown'],"controlregion",sample,sys='jesDown')
    
    dfs_sample = pd.concat([dfs_sampleSRN,dfs_sampleCRN,dfs_sampleSRU,dfs_sampleCRU,dfs_sampleSRD,dfs_sampleCRD])
    
    # apply weight to columns
    dfs_sample['sum_w']*=event_weight
    dfs_sample['sum_ww']*=event_weight*event_weight
    
    # add the new samples into our dataframe for signal and control regions
    dfs = pd.concat([dfs,dfs_sample],ignore_index=True)
# Out:
# data
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/07FC2CD2-106C-4419-9260-12B3E271C345_flat.root
# 1 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/0935DABA-2ECA-4F6B-A880-34594A5AE8FA_flat.root
# 2 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/0B54B6B7-3F0C-4106-BEF6-C64CDE42CB72_flat.root
# 3 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/1130E0AD-1ED1-4B31-AC3E-DC61B5D79552_flat.root
# 4 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/12FBD489-A0D5-4DCF-AE97-59C79EE59964_flat.root
# 5 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/147AD171-2B23-4E8D-83FF-0D632170BA4E_flat.root
# 6 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/16C24360-0D8E-4FC1-8FC3-D9299BB73685_flat.root
# 7 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/175C8ECA-D1EC-4A13-A178-47A69CB1800F_flat.root
# 8 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/1AFCEE9C-1BE5-41DD-8B9D-6AF9462E8968_flat.root
# 9 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/1DD1CEEB-D37D-4260-8DA4-04E47C2B716C_flat.root
# skipped file (XRootD error)
# 10 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/281911DD-46D2-4D85-8DBC-8ED16C8F5A95_flat.root
# 11 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/2A298552-0142-4ECE-A51A-8B33AE809276_flat.root
# 12 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/4315DF6C-ECD0-428C-8C95-1991B9BCD0FD_flat.root
# 13 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/4849BA7C-0D64-4C64-868C-BA8D5D8CAD21_flat.root
# 14 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/4B314AB4-380C-47A0-A62B-E82BC2BA58F5_flat.root
# 15 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/573262AD-9C84-453A-898E-CEFEEDFDC541_flat.root
# 16 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/5994FACC-E71F-4501-8C73-21764F2E5730_flat.root
# 17 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/5DD24894-A5FE-48D4-B2EE-57C0E40ABD56_flat.root
# 18 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/76ECD3B5-9006-428A-AC8E-A4E4FA807BD3_flat.root
# 19 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/7BABE23F-41E1-4633-9F72-27239D1DD908_flat.root
# skipped file (XRootD error)
# 20 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/7C7E1B48-DEFD-4936-8E85-2E28A7612082_flat.root
# 21 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/7CD7A3D3-2600-4091-8453-9D73301D1E44_flat.root
# 22 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/7EC10C02-5BFB-4FFF-91F8-8173BCD796FF_flat.root
# 23 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/889B92EC-07C1-4BF6-8E45-A67F61FE5349_flat.root
# 24 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/8A132E47-7768-4D32-B09D-D3CAE4A9A347_flat.root
# 25 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/8DA7FEA1-2B5E-4A1B-BEDD-F107F11974C3_flat.root
# 26 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/8FA2101C-601D-4D4F-8703-7D995B84CBB3_flat.root
# 27 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/980E97AA-1C75-4F04-9D0C-63E1490C8F5A_flat.root
# 28 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/9E786D5C-BA52-485D-AB84-C67F226F2F58_flat.root
# skipped file (XRootD error)
# 29 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/A6AC772D-425F-4CD2-8322-C8FEE5C99139_flat.root
# 30 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/B33644DB-667C-4D6D-A37D-B97F570F071A_flat.root
# 31 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/B48442A0-44AD-4274-A817-1D19F85F12F6_flat.root
# 32 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/BA9C717D-82A2-4B5A-BA70-0D437FDB7C75_flat.root
# skipped file (XRootD error)
# 33 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/C1D64D4F-BE89-4900-BA27-4B961F3D628E_flat.root
# 34 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/C58775CB-19DB-4DC8-9B08-7CFE0BE8083F_flat.root
# skipped file (XRootD error)
# 35 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/C6288579-D145-4841-8558-D33D393FE4ED_flat.root
# 36 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/C83CDEA8-0648-427A-8C9A-929E9D705E04_flat.root
# skipped file (XRootD error)
# 37 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/CC849BD5-64E4-4E0C-8382-65E19FE90EF3_flat.root
# 38 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/D2947CEF-CC9E-4DA6-8B00-C6C340C1B8B6_flat.root
# 39 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/D556CF6C-054A-48C7-AAC4-342C73CC2437_flat.root
# 40 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/D9A07110-3040-4F45-B3D9-FBFE859E094E_flat.root
# 41 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/E4F1B731-0937-4114-8EF5-0190BB7E7AC2_flat.root
# 42 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/E80655EE-CE94-4212-AA6D-4D018477B870_flat.root
# 43 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/E939AB04-CFD5-4130-B10B-0167F4C93643_flat.root
# 44 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/ED3100F6-3F92-4982-8169-8112E4D95AFC_flat.root
# 45 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/F80F0BF0-AC5F-4050-90A0-C99FBFFB9C52_flat.root
# 46 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleMuon_flat/FE12438A-4311-4319-97FA-9C2216976C53_flat.root
# 47 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/0A6D49EC-50AB-47FF-9B02-112287C3D2B7_flat.root
# 48 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/0A794A79-0F86-4D69-B306-B698D4591F04_flat.root
# 49 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/0C928531-C5B4-4618-9B0F-4716ECFBF1B5_flat.root
# 50 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/0E97FA46-3B15-453F-8BB7-DFEAC16B37DB_flat.root
# skipped file (XRootD error)
# 51 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/161A4CF3-18DC-4D3D-B982-DD05F6ED11ED_flat.root
# 52 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/1EE8FEBD-C126-4866-8A17-9537E414D657_flat.root
# 53 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/24A814F8-11BD-4748-87DF-4CB9E3C09250_flat.root
# 54 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/25B8C3DF-9E1F-44B5-A6DD-7F3646BC95F1_flat.root
# 55 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/2A01F7ED-ACD0-4AF0-84C5-3751857B0D8F_flat.root
# 56 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/2B645D77-086B-43C8-8CF3-A6468BB94821_flat.root
# 57 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/2C3F020E-FEE3-4035-B11D-98240E52014B_flat.root
# 58 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/2D2B84DF-F9EC-4E0E-BD25-1C0A7A34BEE5_flat.root
# 59 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/334D7957-270E-4DFA-AA16-759647A9CC0E_flat.root
# 60 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/3E054BBD-5A97-4BB9-B3A8-215391A7D46B_flat.root
# 61 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/3F1DB48C-8A8D-4C11-9E0F-78C656E1E6D3_flat.root
# 62 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/478D2CF5-47B2-4031-9250-15235EB00359_flat.root
# 63 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/49BA3F0F-BDA7-4B66-B4A2-03FF0C4F28AA_flat.root
# 64 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/4D36114E-F596-4370-A8C3-A0D7C300085E_flat.root
# 65 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/4F8A68CB-8B09-4DAA-B215-B4A1685A89AE_flat.root
# 66 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/511BF27A-5A70-4E08-A110-C050E7FAA906_flat.root
# 67 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/53B0CC9C-CAA1-4F79-923C-13A5ADA8EF73_flat.root
# 68 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/5696C70D-5AC5-4B43-A639-173E26166A80_flat.root
# 69 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/592E307C-364F-4ED7-8440-014B15F73FC0_flat.root
# skipped file (XRootD error)
# 70 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/5BD81FFE-FDF3-44B8-8486-9A5B960B3AD5_flat.root
# 71 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/5E2AC014-5AFE-43DD-9654-F563E97A087C_flat.root
# 72 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/61BD6918-9AEE-47CA-AB6F-B80AFAFDBAFE_flat.root
# 73 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/6551AFCA-8017-47CB-B28C-FDE8569969DC_flat.root
# 74 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/678D3B74-113A-427A-9A53-8D302845E02F_flat.root
# 75 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/6B14F64D-27A4-4B71-84E8-8D1991D8C973_flat.root
# 76 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/6DD0D641-207C-4F30-B0F9-2BFCEFF318FD_flat.root
# 77 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/72B94931-225D-47AA-865F-218733C2E0A0_flat.root
# 78 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/74D65F89-0029-4827-A59F-6BD4A6A79B5B_flat.root
# 79 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/78E94491-C139-492F-8C0F-A42FC60E3282_flat.root
# skipped file (XRootD error)
# 80 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/7C17C0AD-7B3E-4147-9872-C1544048C9A1_flat.root
# 81 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/7CDDB16D-7477-48F8-B68F-4BEDADB71D84_flat.root
# 82 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/87A90D74-09F6-4C66-A386-5BD734BDBC1D_flat.root
# 83 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/8F2BF4A9-FEB8-44AC-A61D-263EC9E967EC_flat.root
# 84 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/8F40A17F-7901-4280-BA45-538B625878E7_flat.root
# 85 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/920C3964-9E3F-40B1-9F1D-B2E7A09EF94F_flat.root
# 86 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/A2C4BC6E-7C4A-43EF-9F31-F993445F0043_flat.root
# 87 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/A6EB3021-073C-4B76-B804-C10BCCF15CC1_flat.root
# 88 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/A8BB2F99-B48B-4B5A-830A-F3A10D8CE708_flat.root
# skipped file (XRootD error)
# 89 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/A8EC4B40-B03F-48AE-9030-5EA89A7F981E_flat.root
# 90 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/AEBED55A-667F-4440-936A-26DA6AF9BEA6_flat.root
# 91 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/B2BD78D2-C1AD-4B81-8A54-2BA9E28C9901_flat.root
# 92 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/B67045EE-59F0-4CDF-9C55-D91B8F61FE82_flat.root
# 93 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/BAB4FC2F-44E7-4ED6-B3E8-C075E1137217_flat.root
# 94 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/C1F43C62-5B20-4561-B449-9F63F4B134E4_flat.root
# 95 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/C449AA5A-EC52-4871-985E-44626E3700D7_flat.root
# 96 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CA890FAA-180F-4679-8030-3460A603FB03_flat.root
# 97 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CAB032CD-63D5-46F5-BF6D-870DA1023447_flat.root
# 98 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CBD5AA59-1842-4903-A625-9104B30211B4_flat.root
# 99 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CCBA7B03-33E2-437B-9A17-D47E35CD9E40_flat.root
# 100 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CD3EB7A6-BC5E-40B8-B1FD-9C027B41F19C_flat.root
# 101 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CDD76FFA-B493-4461-B37B-31029215BDC8_flat.root
# 102 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CEF6CFE8-DE3C-44D4-984E-FCF9233B3032_flat.root
# 103 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/CF820E64-CE9F-4A15-B613-61F338D108DB_flat.root
# 104 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/D0A1E881-0515-4B29-BA0D-FB16AB930F8C_flat.root
# 105 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/D3E4D46E-27A7-4D61-9B86-0BCBE59BDA29_flat.root
# 106 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/D45EB7ED-404C-4258-B7A7-967BFE198E3D_flat.root
# 107 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/D4832DE0-2553-4AFD-8ABA-2D3D7CAA7822_flat.root
# 108 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/D616087C-5AAF-4464-AA0D-2CC8C8F32304_flat.root
# 109 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/DE102D61-B015-471A-80CD-18A5E40E9D78_flat.root
# 110 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/DE1F73DD-23E1-446D-9560-2312F7841C80_flat.root
# 111 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/DE26570C-5764-4FAE-B12F-7C7A4A88DBE3_flat.root
# 112 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/DF7B38B4-B3EB-4FA2-905B-BEEB9FB9BF42_flat.root
# 113 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/E229EFF7-5FAF-4690-9C52-39C72F586B5B_flat.root
# 114 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/E76864BD-A7D4-45AD-9D27-1A1F09791D58_flat.root
# 115 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/E8E049D9-19E5-4E46-820D-7BADEFD5A7E1_flat.root
# 116 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/F010D444-F063-44A3-A129-ACA7F7C7FFF4_flat.root
# 117 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/F14954BA-7198-4617-AE42-9C1364873740_flat.root
# skipped file (XRootD error)
# 118 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/F36DA159-8599-4E04-8FEE-C4E1316C619F_flat.root
# 119 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/F7F77C42-2A1B-46A5-9BAE-85D30FBC7A01_flat.root
# 120 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/Run2015D_SingleElectron_flat/FE4CD54E-A8A0-41EC-89ED-DA6076C4BFAD_flat.root
# Data total events accessed 32976537  -> 2031.94 /pb
# ttbar
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/00EFE6B3-01FE-4FBF-ADCB-2921D5903E44_flat.root
# 1 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/032F6482-603E-4A45-AAFA-C3F7DCB4DBC4_flat.root
# /usr/local/venv/lib/python3.10/site-packages/awkward/_connect/_numpy.py:197: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(
# 2 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/098147D8-1FF6-4075-B55A-5784BAD842AB_flat.root
# 3 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/0A514982-0995-497E-9B65-B754B4B0E796_flat.root
# 4 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/0A688F77-7EA0-4935-B33C-56CE7AA786E2_flat.root
# 5 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/0C031340-8011-496F-BADB-30D042E09228_flat.root
# 6 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/12D782DF-337C-41E0-98F2-7E9B10E9B932_flat.root
# 7 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/13BF7F15-9EBD-4ABF-BD01-81262A7CCE29_flat.root
# 8 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/13E3BA98-5DE7-4585-85D1-46F42C4D43CC_flat.root
# 9 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/19367A01-59FE-4EA3-B299-61E1A2AD4C0E_flat.root
# 10 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/1B4D6228-7959-461F-8AA2-DDFFBF9FB970_flat.root
# 11 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/239EE523-1BD3-4C78-ACE7-F9DF220CDD11_flat.root
# 12 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/28D5F4E0-E328-4CA7-B211-82FE43E5B081_flat.root
# 13 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/30FA9C4D-5BD0-4BF3-A653-635615668760_flat.root
# 14 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/3870D5F5-B0C3-4D85-B41D-B2B6C2DC0409_flat.root
# 15 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/3A677B6E-5753-4D2D-A6B7-3826968C7BA0_flat.root
# 16 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/3D8CF094-4BEB-4929-AA92-F43EA5E098CF_flat.root
# 17 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/3F192B5C-3DDF-4FF4-A712-BAC2811F699D_flat.root
# 18 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/4296426F-3CCB-4178-9F98-0BC642165B3D_flat.root
# 19 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/4478276D-C04C-4B77-9EB5-F79EB5AD7A05_flat.root
# 20 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/46CE0F2B-54E2-4E8D-8325-B2A3ADCE9D08_flat.root
# 21 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/49B4B180-983A-440A-AE58-391B837E9DFD_flat.root
# 22 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/4C7420E7-14B8-4441-A38B-F6FC831819C9_flat.root
# 23 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/5C4CEC48-D416-4A3A-948A-8CE952B1EB03_flat.root
# 24 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/5E34CE76-1BA3-4A20-B828-A008E2331C0D_flat.root
# 25 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/62BF6012-EF8C-4EC4-A123-417558A9CCB1_flat.root
# 26 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/631000A1-01EF-46D5-8B49-14A0201AEBE2_flat.root
# 27 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/63D63244-E9C1-4AB3-93B3-71F6AB045310_flat.root
# skipped file (XRootD error)
# 28 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/6907900D-9183-405F-9E15-CCA7FBFD2844_flat.root
# skipped file (XRootD error)
# 29 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/6A4134C7-ABF8-4B93-A4C4-4B6A14D3EFA7_flat.root
# 30 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/6B888D96-9FC8-499B-9610-9021F5A3C791_flat.root
# 31 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/6D5A8366-FEA3-4C76-BD4E-22B56D367281_flat.root
# 32 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/75D1ECE0-9164-4D54-B7D0-D925F8ED6539_flat.root
# skipped file (XRootD error)
# 33 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/7B495019-1D94-4858-9AA5-15C41B1FB1E4_flat.root
# 34 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/7E41828E-AE31-43E9-97CA-0BE5772C24F2_flat.root
# 35 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/7EA814EE-1F4E-4333-A7A5-7B15C77BDA9C_flat.root
# 36 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/7F8993D1-8A36-4883-90B1-4536CAD2252E_flat.root
# skipped file (XRootD error)
# 37 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/81495E76-2753-40B4-9B86-38E362D9D2DB_flat.root
# 38 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/8350E004-70B6-4AEC-A992-469B0162FDCF_flat.root
# 39 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/8470C31C-747B-4FB2-8266-714B1F126058_flat.root
# 40 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/898502E8-B524-4A01-883B-4B88B5A6491F_flat.root
# skipped file (XRootD error)
# 41 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/8DF98CB5-23EB-4E23-99D4-FA4895606009_flat.root
# 42 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/8E133C03-B881-4079-AE85-C7233FF4F50A_flat.root
# 43 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/931049CD-3179-4A39-B4D6-B245512289DA_flat.root
# 44 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/975227F9-7D76-405E-9147-8512E55BF756_flat.root
# 45 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/A0AC60C0-FBC2-4A6D-A11C-BEB464F972B9_flat.root
# 46 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/AAC00CD7-3BE7-438B-8353-A8E029BA3D79_flat.root
# 47 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/B731E479-15A2-4E5E-BDF5-ADA645CEC3C1_flat.root
# 48 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/B78FC740-2AB8-4C06-AD14-A4FA1B92640C_flat.root
# skipped file (XRootD error)
# 49 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/BC0DA9C3-E624-4BDB-8D8C-223FF4B7CC99_flat.root
# 50 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/C52D903A-E895-4270-93B9-1CAC31FB7119_flat.root
# 51 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/C6E93A33-1B7D-47D3-B35C-DA31EAF492AF_flat.root
# 52 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/D13671F6-2D51-44C2-9B49-E55E854D9F6C_flat.root
# 53 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/D25E2949-CC59-4583-A862-B8DE4C75A0D3_flat.root
# skipped file (XRootD error)
# 54 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/DAE06E34-683D-4E61-B875-C49C3F5A1990_flat.root
# 55 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/E728E0FD-BF02-4588-B0DE-47282A80BA5B_flat.root
# 56 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/ECA5F037-E7F5-4C59-B670-B74B25E1547F_flat.root
# 57 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/EE0CD917-5D9C-4AC9-AAD5-BB39BF5F2C8A_flat.root
# 58 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/FB2827D8-80A1-4A11-84DA-21267635A53B_flat.root
# 59 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TT_TuneCUETP8M1_13TeV-powheg-pythia8_flat/FEB14C8B-49F8-4E4C-B917-19230E2C1A88_flat.root
# Total events processed (ttbar): 18251418 XSec =  831.76 Filter efficiency =  0.2104 Event weight =  0.019483085549135408
# single_atop_t_chan
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_antitop_4f_leptonDecays_13TeV-powheg-pythia8_TuneCUETP8M1_flat/4C71EC69-2C93-4509-AB6D-6D97AD70B140_flat.root
# Total events processed (single_atop_t_chan): 526114 XSec =  26.38 Filter efficiency =  0.32259 Event weight =  0.03286672384263668
# single_top_t_chan
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/1E1D11DC-037C-476D-A1D0-39A0D90141F1_flat.root
# 1 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/1E794138-E67D-4C03-B649-DA69402F2CA6_flat.root
# 2 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/241124EF-CCE6-4977-9465-A0C4B6FFAA9B_flat.root
# 3 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/474A7D6C-3F97-46C0-B575-1710826C7992_flat.root
# 4 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/649B26DE-302B-482F-ACDF-724E9355143A_flat.root
# 5 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/66BFC62C-B9F6-4773-9DCF-A5F958F2F7D4_flat.root
# 6 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/A56D4CAB-1AA5-461F-86BD-EFE0C9B83924_flat.root
# skipped file (XRootD error)
# 7 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/AFDB4BFD-8DD8-4732-BA53-3F259F608EA5_flat.root
# 8 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/CF0EEC86-D244-42F1-A5A8-1949771732BB_flat.root
# 9 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/E26EF510-36DB-4B0C-A51A-9EF7422403E4_flat.root
# 10 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_t-channel_4f_leptonDecays_13TeV-amcatnlo-pythia8_TuneCUETP8M1_flat/F6B976C8-0711-4B71-92B2-56883CFA2E62_flat.root
# skipped file (XRootD error)
# Total events processed (single_top_t_chan): 4955881 XSec =  44.33 Filter efficiency =  0.302207 Event weight =  0.005492776954561151
# single_top_tW
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_tW_top_5f_inclusiveDecays_13TeV-powheg-pythia8_TuneCUETP8M1_flat/D4B6F1FF-FC96-4D8C-BCBE-51C2C038DA53_flat.root
# 1 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_ST_tW_antitop_5f_inclusiveDecays_13TeV-powheg-pythia8_TuneCUETP8M1_flat/5CF71E92-2C15-4476-9CFB-FDA53F431351_flat.root
# Total events processed (single_top_tW): 450358 XSec =  71.2 Filter efficiency =  0.2252 Event weight =  0.0723437605937244
# wjets
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/033BAEF7-7C0E-414A-932C-F57D403583B4_flat.root
# 1 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/0456690D-8B07-4F7D-83E7-1FC091981C5C_flat.root
# 2 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/07373260-B335-43C5-A5D9-4833863A4564_flat.root
# 3 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/0A617241-0E78-40B9-A878-8491764F9373_flat.root
# 4 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/0AD0D87C-B220-4A0F-AD19-3C21F5602596_flat.root
# 5 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/0C62B05E-F153-4ECC-8BE1-8ABB1A93F7F4_flat.root
# 6 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/0EA41BA5-6CBD-40EC-8D6C-B62B75F099A2_flat.root
# 7 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/111438D6-7387-4FAC-9B51-997971BA45B8_flat.root
# 8 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/13040F44-C9D5-4867-9F2B-B6A8C0F18BEE_flat.root
# 9 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/1376347F-B662-4A8A-B056-89BBF4E98E8B_flat.root
# 10 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/13CA36DC-BCF9-4FD4-A4DD-9B24E7EEF9EB_flat.root
# 11 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/14E5E7E9-CD8D-4077-970C-F191F2DFAC8B_flat.root
# 12 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/181DF495-65AD-4DF9-978F-BD824F5BFE9D_flat.root
# 13 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/188C8D47-71A9-4A3C-9207-CFEFD9DE050F_flat.root
# 14 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/1C26A469-CF7A-4580-BE91-FD9FAEDC38A4_flat.root
# 15 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/1DC15DE7-EC56-4566-BBD0-4818402D55F5_flat.root
# 16 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/215CBFA9-3631-4F3F-A177-C862BEAB2D75_flat.root
# 17 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/219CD283-38AE-4800-B157-ADDF45EA60E4_flat.root
# 18 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/21C73C01-250A-4ADE-B4BB-46FA52D35A99_flat.root
# 19 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/224E4141-43D3-4712-86FA-4F7F3500CF2F_flat.root
# 20 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/276D3B57-D5C8-4F76-8D1F-95F92F51609D_flat.root
# 21 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/29302F46-151B-4ADB-9866-10583F1975D9_flat.root
# 22 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/2D7EA79C-BB64-4891-9A25-04E6DA1C8436_flat.root
# 23 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/305A3AE5-A765-45A7-9954-3B7A9703FC11_flat.root
# 24 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/3773839B-9EF9-48F5-ADEE-29E6ACE4B323_flat.root
# 25 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/38091F8F-59FA-47CA-B705-389EF11F95A7_flat.root
# 26 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/420D2E8F-BB78-4577-B2CC-845A41969E49_flat.root
# 27 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/4384B298-62C8-4CBA-9D9B-5851770E2DE2_flat.root
# 28 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/48488B99-9EAE-46F7-8E76-CFB2F8D9F116_flat.root
# 29 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/4AE41FBC-7754-4E36-99B2-700CB7CF6944_flat.root
# 30 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/4C6EF2E3-746E-49AB-9AE9-FA0DCF7087D9_flat.root
# 31 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/4D263D5C-A9ED-41C7-ADC5-0D9EC2BB14E4_flat.root
# 32 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/4EFB10E4-392E-4AA3-9AB5-E634DBC4C429_flat.root
# 33 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/55DE3C36-2F6D-43E5-8640-180341E1E7FE_flat.root
# skipped file (XRootD error)
# 34 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/56D7E2FC-18AB-4AA5-8A55-7858633545FE_flat.root
# 35 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/57D37FEC-4EDD-4290-B8C7-1D9FC4E78331_flat.root
# 36 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/593D6801-939E-4D33-9422-358BA652DA25_flat.root
# 37 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/5DBD48CC-7041-41B7-A630-7480458F3496_flat.root
# 38 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/612E4E7A-D700-467B-951D-5FB918BA6C6C_flat.root
# 39 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/6270C2B9-8B74-47A3-8A5A-9B1647DCEEB5_flat.root
# 40 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/6381C541-03A6-491A-9A7C-13697E906DD7_flat.root
# 41 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/642F4D9D-7807-413B-9F53-8578734FFD6A_flat.root
# 42 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/64D115C9-ED44-43D1-9A89-6D6553FE8E22_flat.root
# 43 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/64D505F9-5F1E-4C72-A86F-579153E8F6C2_flat.root
# 44 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/6F4E6E23-18A1-4A3A-B735-4B7FBC164233_flat.root
# 45 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/709F19A0-7F0F-4960-9525-8A4A8E4FA452_flat.root
# 46 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/70CE10BB-8CB7-4DA0-B058-EADD521D0DD5_flat.root
# 47 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/70F8255C-25B9-4D03-B9A4-A9E87E76303A_flat.root
# 48 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/75C5B98A-BE4D-4D0A-B9D9-EC93124F8CAF_flat.root
# 49 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/765DE6DB-8BB7-41DB-BEBF-2005D76A9E33_flat.root
# 50 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/79E50315-487D-414E-9769-25CF8732CA1D_flat.root
# 51 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/7A487EC5-F438-4DB1-9690-7CAF05E9D8F9_flat.root
# 52 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/7C1A8B65-47C2-4D8D-9F50-74097EA01469_flat.root
# 53 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/7F80DDF1-14D0-467A-98DE-BCA07AAF28F5_flat.root
# 54 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/7FD18E7B-ECE0-4D54-B617-B7630EA7B35F_flat.root
# 55 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/822E4CAD-8C83-4A65-93AA-345848A169CC_flat.root
# 56 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/84C77FE4-ACC2-4327-9567-CB80E649660F_flat.root
# skipped file (XRootD error)
# 57 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/8725BF50-4732-400D-8A4E-2D3357B9D4C3_flat.root
# 58 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/87A76DA2-214B-43B6-9C4A-4ECC4A03CC9D_flat.root
# skipped file (XRootD error)
# 59 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/89F947B7-27B1-4B86-B4B8-BAC61B5A17B8_flat.root
# 60 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/8A2EE458-EC46-4035-A2AF-266D4BD51839_flat.root
# 61 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/8CD6F8C9-33A1-4763-91BB-6AEE5601916D_flat.root
# 62 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/8FB353F5-4223-49F7-AA14-BE6D5B38D333_flat.root
# 63 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/9283AE0B-2018-4A9E-AD50-48E85DF8BBED_flat.root
# 64 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/944E7544-0F9A-421D-8D0F-5C595F0BF03B_flat.root
# 65 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/96B05CD2-8D08-466B-A2DA-26C9AE154A75_flat.root
# 66 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/9D476BB9-E612-4561-9E0E-3F0A428A197D_flat.root
# 67 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/A223D071-97C0-4D3D-A12C-F551D98AEEAE_flat.root
# 68 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/A22B53D7-5EEF-41E1-AC20-DD1BEB0B65BC_flat.root
# 69 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/A62D4640-E2CA-406C-8FFD-6656D9615AC0_flat.root
# 70 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/A6CA4927-AD67-40D0-9275-AC5A2FFDCFDA_flat.root
# 71 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/AA94E533-BA54-41D0-A763-BF498911B71F_flat.root
# 72 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/ACA71BD6-0B03-4E38-938D-F012350C4AFC_flat.root
# 73 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/AEC34FBC-08D8-4DB0-9C8F-E06DCD93D30F_flat.root
# 74 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/AF67E2F5-8F6C-4804-9047-E9C38494341B_flat.root
# 75 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/B0C855B8-907E-4A3E-9BD7-1F0947CA60D1_flat.root
# 76 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/B55F8D75-B4BF-4490-BF80-E407945C36B7_flat.root
# 77 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/B7B00C37-8ED6-4295-B91A-8C5AA915937D_flat.root
# 78 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/B99BC674-EBCD-4E62-B165-C4F637800C26_flat.root
# 79 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BA8C9346-7C4B-489B-B589-959BC802205E_flat.root
# 80 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BAB2AB56-2174-4B61-9605-39B1A85DEFF1_flat.root
# 81 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BB71ADF6-7176-4557-A206-ACE8BE0DC347_flat.root
# 82 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BCCFE457-04E9-488C-BF68-AF96CF0E257E_flat.root
# 83 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BD9B0D33-D488-4AFE-AB03-9A58E4EDB81D_flat.root
# 84 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BDBD247A-2943-44FF-8940-DC0FB394679E_flat.root
# 85 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BEC79605-13CD-4E09-AB91-D0B23133C2EF_flat.root
# 86 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/BF3DD150-CD21-4CEE-B7CB-BE26BEF51B7F_flat.root
# 87 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/C17203D4-678A-46D9-B732-5443010BC76C_flat.root
# 88 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/CBB391DD-774F-43F0-82EF-A8A01A280448_flat.root
# 89 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/CCD61A47-FE94-4033-92FE-A188E527A07F_flat.root
# 90 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/CE129C44-BB10-4875-B47E-9FAB4988499F_flat.root
# 91 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/CF5DB779-E884-424C-89FF-861C93962AF9_flat.root
# 92 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/D4518931-FAA6-499E-A301-7620B554F7C4_flat.root
# 93 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/D5398727-3347-4B10-A390-BDBC8C56A269_flat.root
# skipped file (XRootD error)
# 94 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/D9B28F23-43EA-457F-B041-8FD6DE851757_flat.root
# 95 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/D9CD26BA-2382-4153-8EA7-E3CC767EE7B4_flat.root
# 96 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/DB4E3FE3-725C-426C-8702-942085EB1217_flat.root
# 97 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/DC00C8DF-C18A-4C30-B1AD-83C63097F7DB_flat.root
# 98 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/DC6DBF17-1C12-4FE6-A52B-63B17C57E06F_flat.root
# 99 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/DE834833-0651-4851-AC84-F190DDF7CB83_flat.root
# 100 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/DF85EED1-BE88-410F-9C15-E46EFC6EE589_flat.root
# 101 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/E31BAE09-ADA1-4DEE-86A0-66F7FD7D2036_flat.root
# 102 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/E43B1A94-C0E8-4541-9ACB-5F2268F55082_flat.root
# 103 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/E6D22EBA-A9D6-4B5F-A914-9A0013A0A5E7_flat.root
# 104 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/E7839C0F-A754-4028-9AA3-29AA6CAC8466_flat.root
# 105 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/EC16F876-0FA3-4320-AFA7-50A81B484784_flat.root
# 106 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/EF213561-A948-4468-8DEF-8AACE12923EF_flat.root
# 107 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/F528120C-2F0D-42C6-90F5-8344FBB324A8_flat.root
# 108 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/F5B6EA7D-E373-49B8-A675-B84C4BA7FED4_flat.root
# 109 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/F5B7B03E-B2B1-4E3E-838B-7BCE13032C93_flat.root
# 110 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/F6B5066A-F7D5-4F6E-9240-596C63248F9A_flat.root
# 111 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/F955695A-1CCD-44BF-9D06-41C6520B0DC5_flat.root
# 112 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/F962B677-938F-4E76-9AC9-007852E390BA_flat.root
# 113 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_WJetsToLNu_TuneCUETP8M1_13TeV-amcatnloFXFX-pythia8_flat/FDFA0225-C350-4845-89D3-EFCBCAFFC5FF_flat.root
# Total events processed (wjets): 37200790 XSec =  61526.7 Filter efficiency =  0.1939 Event weight =  0.6516281708108391
# tprime
# 0 root://eospublic.cern.ch//eos/opendata/cms/derived-data/POET/23-Jul-22/RunIIFall15MiniAODv2_TprimeTprime_M-1200_TuneCUETP8M1_13TeV-madgraph-pythia8_flat/5A744C3D-EA4C-4C35-9738-BF878E063562_flat.root
# Total events processed (tprime): 253993 XSec =  0.0118 Filter efficiency =  1.0 Event weight =  9.439974957837604e-05

# %%
print(dfs)
plt.rcParams.update({'font.size': 18})

order_sim = samples[1:-1] # don't include the signal in the stack
order_sim.reverse() # plot stack in reverse 
n_sim_samples = len(order_sim)

# need to make list structures for this to work in stacked mode 
bin_centres = np.array(obsbins)+(obsbins[1]-obsbins[0])/2
bins_list = [obsbins for b in range(n_sim_samples)]
samples_stack = [dfs[ (dfs['process']==s) & (dfs['systematic']=='nominal') & (dfs['channel']=='signalregion')]['sum_w'].to_list() for s in order_sim]
labels = order_sim

plt.figure(figsize=(11,8))

plt.hist(bins_list,bins=obsbins,weights=samples_stack,label=labels,stacked=True,density=False)
plt.errorbar(bin_centres,dfs[ (dfs['process']=='data') & (dfs['systematic']=='nominal') & (dfs['channel']=='signalregion')]['sum_w']
             ,yerr     =(dfs[ (dfs['process']=='data') & (dfs['systematic']=='nominal') & (dfs['channel']=='signalregion')]['sum_ww'])**0.5
             ,label='data (%.2f $fb^{-1}$)'%(intlumi/1000)
             ,marker='o'
             ,markersize=3.2
             ,color='black'
             ,linestyle="none")
plt.hist(obsbins,bins=obsbins
         ,weights=dfs[ (dfs['process']=='tprime') & (dfs['systematic']=='nominal') & (dfs['channel']=='signalregion')]['sum_w']*200
         ,color='cyan'
         ,histtype='step'
         ,linewidth=3
         ,label='$200\\times$ tprime - $m_{T}=1.2$ TeV'
        )
plt.xlabel("$m_{bjj}$ (GeV)")
plt.ylabel("Events")
#plt.yscale('log')
plt.legend()
plt.tight_layout()
print("Integrated luminosity = ", intlumi," /pb")

plt.savefig("search_mbjj_signalregion.png")
# Out:
#            channel process systematic  bin        sum_w       sum_ww
# 0     signalregion    data    nominal    0  2196.000000  2196.000000
# 1     signalregion    data    nominal    1  1272.000000  1272.000000
# 2     signalregion    data    nominal    2   744.000000   744.000000
# 3     signalregion    data    nominal    3   448.000000   448.000000
# 4     signalregion    data    nominal    4   282.000000   282.000000
# ..             ...     ...        ...  ...          ...          ...
# 755  controlregion  tprime    jesDown   15     0.031341     0.000003
# 756  controlregion  tprime    jesDown   16     0.023978     0.000002
# 757  controlregion  tprime    jesDown   17     0.019352     0.000002
# 758  controlregion  tprime    jesDown   18     0.012366     0.000001
# 759  controlregion  tprime    jesDown   19     0.000000     0.000000
#
# [760 rows x 6 columns]
# Integrated luminosity =  2031.9386097169888  /pb

# %%
# need to make list structures for this to work in stacked mode 
samples_stack = [dfs[ (dfs['process']==s) & (dfs['systematic']=='nominal') & (dfs['channel']=='controlregion')]['sum_w'].to_list() for s in order_sim]

plt.figure(figsize=(11,8))

plt.hist(bins_list,bins=obsbins,weights=samples_stack,label=labels,stacked=True,density=False)
plt.errorbar(bin_centres,dfs[(dfs['process']=='data') & (dfs['systematic']=='nominal') & (dfs['channel']=='controlregion')]['sum_w']
             ,yerr     =(dfs[(dfs['process']=='data') & (dfs['systematic']=='nominal') & (dfs['channel']=='controlregion')]['sum_ww'])**0.5
             ,label='data (%.2f $fb^{-1}$)'%(intlumi/1000)
             ,marker='o'
             ,markersize=3.2
             ,color='black'
             ,linestyle="none")
plt.hist(obsbins,bins=obsbins
         ,weights=dfs[ (dfs['process']=='tprime') & (dfs['systematic']=='nominal') & (dfs['channel']=='controlregion')]['sum_w']*200
         ,color='cyan'
         ,histtype='step'
         ,linewidth=3
         ,label='$200\\times$ tprime - $m_{T}=1.2$ TeV'
        )
plt.xlabel("$m_{jjj}$ (GeV)")
plt.ylabel("Events")
#plt.yscale('log')

plt.legend()
plt.tight_layout()
print("Integrated luminosity = ", intlumi," /pb")

plt.savefig("search_mbjj_controlregion.png")
# Out:
# Integrated luminosity =  2031.9386097169888  /pb

# %%
# sort the dataframe to avoid warnings later
dfs = dfs.sort_values(by=['channel','process','systematic','bin'])

# Finally save histograms to a csv file
dfs.to_csv('tprime_1200GeV_search_allregions_mbjj.csv',index=False)
